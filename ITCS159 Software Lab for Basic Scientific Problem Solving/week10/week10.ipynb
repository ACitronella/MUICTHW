# %%
import sys
import scipy
import numpy
import matplotlib
import pandas
import sklearn
print ('Python : {} '. format (sys. version ) )
print ('scipy : {} '. format ( scipy . __version__ ) )
print ('numpy : {} '. format ( numpy . __version__ ) )
print ('matplotlib : {} '. format ( matplotlib . __version__ ) )
print ('pandas : {} '. format ( pandas . __version__ ) )
print ('sklearn : {} '. format ( sklearn . __version__ ) )
import pandas
from pandas . plotting import scatter_matrix
import matplotlib . pyplot as plt
from sklearn import model_selection
from sklearn . neighbors import KNeighborsClassifier
# Out:
# Python : 3.9.6 (default, Jul 30 2021, 11:42:22) [MSC v.1916 64 bit (AMD64)]
# scipy : 1.7.1
# numpy : 1.20.3
# matplotlib : 3.4.2
# pandas : 1.3.3
# sklearn : 1.0

# %% [markdown]
# ## Exercise 3) Next, load the iris dataset from file. Please ensure that the download file named  iris.data’ is located in the same folder as the python file (created from Jupyter Notebook).

# %%
names = ['sepal - length', 'sepal - width', 'petal - length', 'petal - width', 'class']
ds = pandas . read_csv ('iris.data', names = names )

# %%
ds
# Out:
#      sepal - length  sepal - width  petal - length  petal - width  \
# 0               5.1            3.5             1.4            0.2
# 1               4.9            3.0             1.4            0.2
# 2               4.7            3.2             1.3            0.2
# 3               4.6            3.1             1.5            0.2
# 4               5.0            3.6             1.4            0.2
# ..              ...            ...             ...            ...
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Exercise 4) Try the following commands to display basic information of iris dataset.

# %%
print (ds. shape )
print (ds. head (20) )
print (ds. describe () )
print (ds. groupby ('class') . size () )
# Out:
# (150, 5)
#     sepal - length  sepal - width  petal - length  petal - width        class
# 0              5.1            3.5             1.4            0.2  Iris-setosa
# 1              4.9            3.0             1.4            0.2  Iris-setosa
# 2              4.7            3.2             1.3            0.2  Iris-setosa
# 3              4.6            3.1             1.5            0.2  Iris-setosa
# 4              5.0            3.6             1.4            0.2  Iris-setosa
# 5              5.4            3.9             1.7            0.4  Iris-setosa
# 6              4.6            3.4             1.4            0.3  Iris-setosa
# 7              5.0            3.4             1.5            0.2  Iris-setosa
# 8              4.4            2.9             1.4            0.2  Iris-setosa
# 9              4.9            3.1             1.5            0.1  Iris-setosa
# 10             5.4            3.7             1.5            0.2  Iris-setosa
# 11             4.8            3.4             1.6            0.2  Iris-setosa
# 12             4.8            3.0             1.4            0.1  Iris-setosa
# 13             4.3            3.0             1.1            0.1  Iris-setosa
# 14             5.8            4.0             1.2            0.2  Iris-setosa
# 15             5.7            4.4             1.5            0.4  Iris-setosa
# 16             5.4            3.9             1.3            0.4  Iris-setosa
# 17             5.1            3.5             1.4            0.3  Iris-setosa
# 18             5.7            3.8             1.7            0.3  Iris-setosa
# 19             5.1            3.8             1.5            0.3  Iris-setosa
#        sepal - length  sepal - width  petal - length  petal - width
# count      150.000000     150.000000      150.000000     150.000000
# mean         5.843333       3.054000        3.758667       1.198667
# std          0.828066       0.433594        1.764420       0.763161
# min          4.300000       2.000000        1.000000       0.100000
# 25%          5.100000       2.800000        1.600000       0.300000
# 50%          5.800000       3.000000        4.350000       1.300000
# 75%          6.400000       3.300000        5.100000       1.800000
# max          7.900000       4.400000        6.900000       2.500000
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
ds. plot ( kind ='box', subplots =True , layout =(2 ,2) , sharex =False , sharey = False )
plt. show ()

# %% [markdown]
# ordinary box plot on each column on the dataset. To looking for outliner, distribution of data, and skewness.

# %%
ds[ds["class"] == "Iris-setosa"]. plot ( kind ='box', subplots =True , layout =(2 ,2) , sharex =False , sharey = False )
plt. show ()

# %%
ds[ds["class"] == "Iris-versicolor"]. plot ( kind ='box', subplots =True , layout =(2 ,2) , sharex =False , sharey = False )
plt. show ()

# %%
ds[ds["class"] == "Iris-virginica"]. plot ( kind ='box', subplots =True , layout =(2 ,2) , sharex =False , sharey = False )
plt. show ()

# %% [markdown]
# ## Exercise 6) Next step is to separate features of iris flower from the target

# %%
array = ds. values
X = array [: ,0:4]
Y = array [: ,4]

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.3, 3.0, 1.1, 0.1],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1.0, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.0, 3.0, 1.6, 0.2],
#        [5.0, 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.0, 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3.0, 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.0, 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5.0, 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3.0, 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5.0, 3.3, 1.4, 0.2],
#        [7.0, 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4.0, 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1.0],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.0, 2.0, 3.5, 1.0],
#        [5.9, 3.0, 4.2, 1.5],
#        [6.0, 2.2, 4.0, 1.0],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3.0, 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1.0],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4.0, 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3.0, 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3.0, 5.0, 1.7],
#        [6.0, 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1.0],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1.0],
#        [5.8, 2.7, 3.9, 1.2],
#        [6.0, 2.7, 5.1, 1.6],
#        [5.4, 3.0, 4.5, 1.5],
#        [6.0, 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3.0, 4.1, 1.3],
#        [5.5, 2.5, 4.0, 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3.0, 4.6, 1.4],
#        [5.8, 2.6, 4.0, 1.2],
#        [5.0, 2.3, 3.3, 1.0],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3.0, 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3.0, 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6.0, 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3.0, 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3.0, 5.8, 2.2],
#        [7.6, 3.0, 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2.0],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3.0, 5.5, 2.1],
#        [5.7, 2.5, 5.0, 2.0],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3.0, 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6.0, 2.2, 5.0, 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2.0],
#        [7.7, 2.8, 6.7, 2.0],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6.0, 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3.0, 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3.0, 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2.0],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3.0, 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.0, 3.0, 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3.0, 5.2, 2.3],
#        [6.3, 2.5, 5.0, 1.9],
#        [6.5, 3.0, 5.2, 2.0],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3.0, 5.1, 1.8]], dtype=object)

# %%
Y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ## Exercise 7) Now you should have X which contain four features of iris flowers and Y which contains target name of iris’ species. Next, we need to split iris.data into two groups (one for training and one for testing).

# %%
test_size = 0.20
seed = 7
X_train , X_test , Y_train , Y_test = model_selection .train_test_split (X, Y, test_size = test_size , random_state = seed)

# %%
X.shape
# Out:
# (150, 4)

# %%
Y.shape
# Out:
# (150,)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
Y_train.shape
# Out:
# (120,)

# %%
Y_test.shape
# Out:
# (30,)

# %% [markdown]
# spliting (randomly) each X and Y into two groups train and test. Size of train and test can be specified by $test_size parameter.

# %% [markdown]
# ## Exercise 8) Try to change the test size and seed number. What will happens? What are the outputs of X train, X test, Y train, Y test?

# %%
test_size = 0.15
seed = 8
X_train , X_test , Y_train , Y_test = model_selection .train_test_split (X, Y, test_size = test_size , random_state = seed)

# %%
X.shape
# Out:
# (150, 4)

# %%
Y.shape
# Out:
# (150,)

# %%
X_train.shape
# Out:
# (127, 4)

# %%
X_test.shape
# Out:
# (23, 4)

# %%
Y_train.shape
# Out:
# (127,)

# %%
Y_test.shape
# Out:
# (23,)

# %% [markdown]
# ## Exercise 9) The K-nearest Neighbors state that the new object will be classified to the majority vote of it k-nearest neighbors. Hence, if we considered k=1 and k=3 as presented in Figure 3, what did you see? What would be the output after classification? Which one is more reliable between setting k=1 or k=3? Should k be Odd or Even number? Why?

# %% [markdown]
# From figure 3, k = 3 looking more reliable then k = 1. Since, gray dot is on the boundary between green and blue so its hard to decide. Choosing k = 1, model just select the one that closest to themselves, but choosing k = 3 model will look wider and select the most popular vote in 3.

# %% [markdown]
# I think k should be prime number that greater than number of class add one. If not draw in popular vote can occur if input data is on the boudary of classes.

# %% [markdown]
# ## Exercise 10) Now, we should be ready to create a training set using the K - nearest Neighbors techniques. In this case, we use 7 neighbors to identified the new object

# %%
irisML = KNeighborsClassifier ( n_neighbors =7)
irisML . fit( X_train , Y_train )
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %% [markdown]
# ## Exercise 11) Try the following command to pass the test dataset to the model for prediction

# %%
prediction = irisML . predict ( X_test )

# %%
prediction
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor'], dtype=object)

# %% [markdown]
# ## Exercise 12) Let’s add the following command to see the score of prediction model:

# %%
irisML . score ( X_test , Y_test )
# Out:
# 0.9565217391304348

# %% [markdown]
# According to sklearn document output number is mean accuracy of the model on X_test, Y_test

# %% [markdown]
# ## Exercise 13) Now, we can try input new iris object to the model in order to classify it specie:

# %%
new_obj1 = [[5.2 ,4.3 ,5.6 ,1.6]]
output1 = irisML . predict ( new_obj1 )

# %%
output1
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
new_obj1 = [[5.0, 3.5, 1.5, 0.25]]
output1 = irisML . predict ( new_obj1 )
output1
# Out:
# array(['Iris-setosa'], dtype=object)
