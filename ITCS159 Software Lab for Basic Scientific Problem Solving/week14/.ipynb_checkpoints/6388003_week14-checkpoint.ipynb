# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# # Tokenization

# %% [markdown]
# ## Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize
text="""Dogs ,Canis lupus familiaris, are domesticated mammals,
not natural wild animals. They were originally bred from
wolves. They have been bred by humans for a long time, and
were the first animals ever to be domesticated.
Today, some dogs are used as pets, others are used to help
humans do their work. They are a popular pet because they
are usually playful, friendly, loyal and listen to humans.
Thirty million dogs in the United States are registered as
pets. Dogs eat both meat and vegetables, often mixed
together and sold in stores as dog food. Dogs often have
jobs, including as police dogs, army dogs, assistance dogs,
fire dogs, messenger dogs, hunting dogs, herding dogs, or
rescue dogs.
They are sometimes called "canines" from the Latin word for dog
- canis. Sometimes people also use "dog" to describe other
canids, such as wolves. A baby dog is called a pup or puppy.
A dog is called a puppy until it is about one year old.
Dogs are sometimes referred to as "man’s best friend" because
they are kept as domestic pets and are usually loyal and
like being around humans."""
tokenized_text = sent_tokenize(text)
print(*tokenized_text, sep="\n\n")
# Out:
# Dogs ,Canis lupus familiaris, are domesticated mammals,
# not natural wild animals.
#
# They were originally bred from
# wolves.
#
# They have been bred by humans for a long time, and
# were the first animals ever to be domesticated.
#
# Today, some dogs are used as pets, others are used to help
# humans do their work.
#
# They are a popular pet because they
# are usually playful, friendly, loyal and listen to humans.
#
# Thirty million dogs in the United States are registered as
# pets.
#
# Dogs eat both meat and vegetables, often mixed
# together and sold in stores as dog food.
#
# Dogs often have
# jobs, including as police dogs, army dogs, assistance dogs,
# fire dogs, messenger dogs, hunting dogs, herding dogs, or
# rescue dogs.
#
# They are sometimes called "canines" from the Latin word for dog
# - canis.
#
# Sometimes people also use "dog" to describe other
# canids, such as wolves.
#
# A baby dog is called a pup or puppy.
#
# A dog is called a puppy until it is about one year old.
#
# Dogs are sometimes referred to as "man’s best friend" because
# they are kept as domestic pets and are usually loyal and
# like being around humans.

# %%
len(tokenized_text)
# Out:
# 13

# %% [markdown]
# There are 13 sentences, seperated by full stop character(".")
#
# The Third sentence is "They have been bred by humans for a long time, and
# were the first animals ever to be domesticated."

# %% [markdown]
# ## Word Tokenization

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(*tokenized_word, sep="\n")
# Out:
# Dogs
# ,
# Canis
# lupus
# familiaris
# ,
# are
# domesticated
# mammals
# ,
# not
# natural
# wild
# animals
# .
# They
# were
# originally
# bred
# from
# wolves
# .
# They
# have
# been
# bred
# by
# humans
# for
# a
# long
# time
# ,
# and
# were
# the
# first
# animals
# ever
# to
# be
# domesticated
# .
# Today
# ,
# some
# dogs
# are
# used
# as
# pets
# ,
# others
# are
# used
# to
# help
# humans
# do
# their
# work
# .
# They
# are
# a
# popular
# pet
# because
# they
# are
# usually
# playful
# ,
# friendly
# ,
# loyal
# and
# listen
# to
# humans
# .
# Thirty
# million
# dogs
# in
# the
# United
# States
# are
# registered
# as
# pets
# .
# Dogs
# eat
# both
# meat
# and
# vegetables
# ,
# often
# mixed
# together
# and
# sold
# in
# stores
# as
# dog
# food
# .
# Dogs
# often
# have
# jobs
# ,
# including
# as
# police
# dogs
# ,
# army
# dogs
# ,
# assistance
# dogs
# ,
# fire
# dogs
# ,
# messenger
# dogs
# ,
# hunting
# dogs
# ,
# herding
# dogs
# ,
# or
# rescue
# dogs
# .
# They
# are
# sometimes
# called
# ``
# canines
# ''
# from
# the
# Latin
# word
# for
# dog
# -
# canis
# .
# Sometimes
# people
# also
# use
# ``
# dog
# ''
# to
# describe
# other
# canids
# ,
# such
# as
# wolves
# .
# A
# baby
# dog
# is
# called
# a
# pup
# or
# puppy
# .
# A
# dog
# is
# called
# a
# puppy
# until
# it
# is
# about
# one
# year
# old
# .
# Dogs
# are
# sometimes
# referred
# to
# as
# ``
# man
# ’
# s
# best
# friend
# ''
# because
# they
# are
# kept
# as
# domestic
# pets
# and
# are
# usually
# loyal
# and
# like
# being
# around
# humans
# .

# %%
len(tokenized_word)
# Out:
# 229

# %%
len(word_tokenize(tokenized_text[0]))
# Out:
# 15

# %%
len(word_tokenize(tokenized_text[-1]))
# Out:
# 30

# %%
len(set(tokenized_word)) == len(tokenized_word)
# Out:
# False

# %% [markdown]
# There are 229 words in the paragraph, seperated by space " " filter LF out
#
# There are 15 words in the first paragraph
#
# There are 30 words in the last paragraph
#
# There exists some words that duplicate

# %% [markdown]
# ## Frequency Distribution

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 120 samples and 229 outcomes>

# %%
fdist
# Out:
# FreqDist({',': 18, '.': 13, 'are': 10, 'dogs': 10, 'as': 7, 'and': 6, 'to': 5, 'dog': 5, 'Dogs': 4, 'They': 4, ...})

# %%
fdist.most_common(10)
# Out:
# [(',', 18),
#  ('.', 13),
#  ('are', 10),
#  ('dogs', 10),
#  ('as', 7),
#  ('and', 6),
#  ('to', 5),
#  ('dog', 5),
#  ('Dogs', 4),
#  ('They', 4)]

# %% [markdown]
# ## Stopwords

# %%
my_stopwords = ["is", "a", "this", ","]

from nltk.corpus import stopwords
nltk_stop_words=set(stopwords.words("english"))
print(nltk_stop_words)
# Out:
# {'me', 'being', 'shan', 'here', 'after', 'but', "you've", 'few', 'at', 's', 'does', 'herself', 'we', 'do', 'before', "wouldn't", 'between', 'you', "shouldn't", 'into', 'with', 'the', 'they', "shan't", 'yourselves', 'there', 'she', 'then', 'her', 'him', 've', 'by', 'of', 'll', 'needn', "isn't", 'why', 'theirs', 'yours', 'no', 'don', 'my', 'own', 'above', 'hadn', 'were', 'when', 'for', 'did', 'just', 'ain', 'this', 'are', 'itself', 'should', 'doesn', "won't", 'while', 'any', 'below', 'been', 'themselves', "you'll", 'on', 'during', 'has', 'further', 'if', 'only', 'ourselves', 'whom', "couldn't", 'that', 'through', 'again', 'both', 'didn', "mustn't", 'm', "didn't", 'our', 'some', 'himself', "mightn't", 'what', 'won', "wasn't", 'be', 'yourself', 'am', "hasn't", 'wouldn', 'was', 'is', "it's", 'as', 'about', 'out', 'o', "should've", 'mustn', 'have', 'aren', 'his', 'shouldn', 'an', 'will', 'their', 'which', 'than', 'until', "aren't", 'mightn', "you're", 'off', 'it', 'now', 'up', 'over', 're', 'not', 'more', "that'll", 'having', 'weren', "needn't", "you'd", "she's", 'your', 'its', "weren't", 'had', 'how', 'haven', 'can', 'i', 'ours', 't', 'and', "don't", 'he', 'where', 'y', 'other', 'too', 'to', 'such', 'd', 'hers', 'these', 'them', 'wasn', 'against', 'couldn', "doesn't", 'in', 'who', 'very', 'down', 'isn', 'once', 'because', 'so', 'hasn', 'from', 'most', 'a', 'ma', 'doing', 'same', 'all', "hadn't", 'under', 'those', "haven't", 'nor', 'myself', 'each', 'or'}

# %% [markdown]
# stopwords can be ommited in many sentences, they are somewhat unnecessary for interpret the meaning of the sentence

# %% [markdown]
# ## Removing Stopwords

# %%
filtered_words=[]
for w in tokenized_word:
    if w not in my_stopwords:
        filtered_words.append(w)
print("Tokenized Sentence:",tokenized_word, len(tokenized_word))
print("\n")
print("Filterd Sentence:",filtered_words, len(filtered_words))
# Out:
# Tokenized Sentence: ['Dogs', ',', 'Canis', 'lupus', 'familiaris', ',', 'are', 'domesticated', 'mammals', ',', 'not', 'natural', 'wild', 'animals', '.', 'They', 'were', 'originally', 'bred', 'from', 'wolves', '.', 'They', 'have', 'been', 'bred', 'by', 'humans', 'for', 'a', 'long', 'time', ',', 'and', 'were', 'the', 'first', 'animals', 'ever', 'to', 'be', 'domesticated', '.', 'Today', ',', 'some', 'dogs', 'are', 'used', 'as', 'pets', ',', 'others', 'are', 'used', 'to', 'help', 'humans', 'do', 'their', 'work', '.', 'They', 'are', 'a', 'popular', 'pet', 'because', 'they', 'are', 'usually', 'playful', ',', 'friendly', ',', 'loyal', 'and', 'listen', 'to', 'humans', '.', 'Thirty', 'million', 'dogs', 'in', 'the', 'United', 'States', 'are', 'registered', 'as', 'pets', '.', 'Dogs', 'eat', 'both', 'meat', 'and', 'vegetables', ',', 'often', 'mixed', 'together', 'and', 'sold', 'in', 'stores', 'as', 'dog', 'food', '.', 'Dogs', 'often', 'have', 'jobs', ',', 'including', 'as', 'police', 'dogs', ',', 'army', 'dogs', ',', 'assistance', 'dogs', ',', 'fire', 'dogs', ',', 'messenger', 'dogs', ',', 'hunting', 'dogs', ',', 'herding', 'dogs', ',', 'or', 'rescue', 'dogs', '.', 'They', 'are', 'sometimes', 'called', '``', 'canines', "''", 'from', 'the', 'Latin', 'word', 'for', 'dog', '-', 'canis', '.', 'Sometimes', 'people', 'also', 'use', '``', 'dog', "''", 'to', 'describe', 'other', 'canids', ',', 'such', 'as', 'wolves', '.', 'A', 'baby', 'dog', 'is', 'called', 'a', 'pup', 'or', 'puppy', '.', 'A', 'dog', 'is', 'called', 'a', 'puppy', 'until', 'it', 'is', 'about', 'one', 'year', 'old', '.', 'Dogs', 'are', 'sometimes', 'referred', 'to', 'as', '``', 'man', '’', 's', 'best', 'friend', "''", 'because', 'they', 'are', 'kept', 'as', 'domestic', 'pets', 'and', 'are', 'usually', 'loyal', 'and', 'like', 'being', 'around', 'humans', '.'] 229
#
#
# Filterd Sentence: ['Dogs', 'Canis', 'lupus', 'familiaris', 'are', 'domesticated', 'mammals', 'not', 'natural', 'wild', 'animals', '.', 'They', 'were', 'originally', 'bred', 'from', 'wolves', '.', 'They', 'have', 'been', 'bred', 'by', 'humans', 'for', 'long', 'time', 'and', 'were', 'the', 'first', 'animals', 'ever', 'to', 'be', 'domesticated', '.', 'Today', 'some', 'dogs', 'are', 'used', 'as', 'pets', 'others', 'are', 'used', 'to', 'help', 'humans', 'do', 'their', 'work', '.', 'They', 'are', 'popular', 'pet', 'because', 'they', 'are', 'usually', 'playful', 'friendly', 'loyal', 'and', 'listen', 'to', 'humans', '.', 'Thirty', 'million', 'dogs', 'in', 'the', 'United', 'States', 'are', 'registered', 'as', 'pets', '.', 'Dogs', 'eat', 'both', 'meat', 'and', 'vegetables', 'often', 'mixed', 'together', 'and', 'sold', 'in', 'stores', 'as', 'dog', 'food', '.', 'Dogs', 'often', 'have', 'jobs', 'including', 'as', 'police', 'dogs', 'army', 'dogs', 'assistance', 'dogs', 'fire', 'dogs', 'messenger', 'dogs', 'hunting', 'dogs', 'herding', 'dogs', 'or', 'rescue', 'dogs', '.', 'They', 'are', 'sometimes', 'called', '``', 'canines', "''", 'from', 'the', 'Latin', 'word', 'for', 'dog', '-', 'canis', '.', 'Sometimes', 'people', 'also', 'use', '``', 'dog', "''", 'to', 'describe', 'other', 'canids', 'such', 'as', 'wolves', '.', 'A', 'baby', 'dog', 'called', 'pup', 'or', 'puppy', '.', 'A', 'dog', 'called', 'puppy', 'until', 'it', 'about', 'one', 'year', 'old', '.', 'Dogs', 'are', 'sometimes', 'referred', 'to', 'as', '``', 'man', '’', 's', 'best', 'friend', "''", 'because', 'they', 'are', 'kept', 'as', 'domestic', 'pets', 'and', 'are', 'usually', 'loyal', 'and', 'like', 'being', 'around', 'humans', '.'] 204

# %%
filtered_words=[]
for w in tokenized_word:
    if w not in stopwords.words("english"):
        filtered_words.append(w)
print("Tokenized Sentence:",tokenized_word, len(tokenized_word))
print("\n")
print("Filterd Sentence:",filtered_words, len(filtered_words))
# Out:
# Tokenized Sentence: ['Dogs', ',', 'Canis', 'lupus', 'familiaris', ',', 'are', 'domesticated', 'mammals', ',', 'not', 'natural', 'wild', 'animals', '.', 'They', 'were', 'originally', 'bred', 'from', 'wolves', '.', 'They', 'have', 'been', 'bred', 'by', 'humans', 'for', 'a', 'long', 'time', ',', 'and', 'were', 'the', 'first', 'animals', 'ever', 'to', 'be', 'domesticated', '.', 'Today', ',', 'some', 'dogs', 'are', 'used', 'as', 'pets', ',', 'others', 'are', 'used', 'to', 'help', 'humans', 'do', 'their', 'work', '.', 'They', 'are', 'a', 'popular', 'pet', 'because', 'they', 'are', 'usually', 'playful', ',', 'friendly', ',', 'loyal', 'and', 'listen', 'to', 'humans', '.', 'Thirty', 'million', 'dogs', 'in', 'the', 'United', 'States', 'are', 'registered', 'as', 'pets', '.', 'Dogs', 'eat', 'both', 'meat', 'and', 'vegetables', ',', 'often', 'mixed', 'together', 'and', 'sold', 'in', 'stores', 'as', 'dog', 'food', '.', 'Dogs', 'often', 'have', 'jobs', ',', 'including', 'as', 'police', 'dogs', ',', 'army', 'dogs', ',', 'assistance', 'dogs', ',', 'fire', 'dogs', ',', 'messenger', 'dogs', ',', 'hunting', 'dogs', ',', 'herding', 'dogs', ',', 'or', 'rescue', 'dogs', '.', 'They', 'are', 'sometimes', 'called', '``', 'canines', "''", 'from', 'the', 'Latin', 'word', 'for', 'dog', '-', 'canis', '.', 'Sometimes', 'people', 'also', 'use', '``', 'dog', "''", 'to', 'describe', 'other', 'canids', ',', 'such', 'as', 'wolves', '.', 'A', 'baby', 'dog', 'is', 'called', 'a', 'pup', 'or', 'puppy', '.', 'A', 'dog', 'is', 'called', 'a', 'puppy', 'until', 'it', 'is', 'about', 'one', 'year', 'old', '.', 'Dogs', 'are', 'sometimes', 'referred', 'to', 'as', '``', 'man', '’', 's', 'best', 'friend', "''", 'because', 'they', 'are', 'kept', 'as', 'domestic', 'pets', 'and', 'are', 'usually', 'loyal', 'and', 'like', 'being', 'around', 'humans', '.'] 229
#
#
# Filterd Sentence: ['Dogs', ',', 'Canis', 'lupus', 'familiaris', ',', 'domesticated', 'mammals', ',', 'natural', 'wild', 'animals', '.', 'They', 'originally', 'bred', 'wolves', '.', 'They', 'bred', 'humans', 'long', 'time', ',', 'first', 'animals', 'ever', 'domesticated', '.', 'Today', ',', 'dogs', 'used', 'pets', ',', 'others', 'used', 'help', 'humans', 'work', '.', 'They', 'popular', 'pet', 'usually', 'playful', ',', 'friendly', ',', 'loyal', 'listen', 'humans', '.', 'Thirty', 'million', 'dogs', 'United', 'States', 'registered', 'pets', '.', 'Dogs', 'eat', 'meat', 'vegetables', ',', 'often', 'mixed', 'together', 'sold', 'stores', 'dog', 'food', '.', 'Dogs', 'often', 'jobs', ',', 'including', 'police', 'dogs', ',', 'army', 'dogs', ',', 'assistance', 'dogs', ',', 'fire', 'dogs', ',', 'messenger', 'dogs', ',', 'hunting', 'dogs', ',', 'herding', 'dogs', ',', 'rescue', 'dogs', '.', 'They', 'sometimes', 'called', '``', 'canines', "''", 'Latin', 'word', 'dog', '-', 'canis', '.', 'Sometimes', 'people', 'also', 'use', '``', 'dog', "''", 'describe', 'canids', ',', 'wolves', '.', 'A', 'baby', 'dog', 'called', 'pup', 'puppy', '.', 'A', 'dog', 'called', 'puppy', 'one', 'year', 'old', '.', 'Dogs', 'sometimes', 'referred', '``', 'man', '’', 'best', 'friend', "''", 'kept', 'domestic', 'pets', 'usually', 'loyal', 'like', 'around', 'humans', '.'] 160

# %% [markdown]
# # Lexicon Normalization

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer
stem = PorterStemmer()
word = "connection"
stem.stem(word)
# Out:
# 'connect'

# %%
stem = PorterStemmer()
stem.stem("connectivity")
# Out:
# 'connect'

# %%
stem = PorterStemmer()
stem.stem("connecting")
# Out:
# 'connect'

# %%
stem = PorterStemmer()
stem.stem("derivational")
# Out:
# 'deriv'

# %%
stem = PorterStemmer()
stem.stem("multiplying")
# Out:
# 'multipli'

# %%
stem = PorterStemmer()
stem.stem("multiplicative")
# Out:
# 'multipl'

# %% [markdown]
# Output of stem function is reduced word(-ish) of that word. By remove suffix such as "ing", "ly"

# %%
stem = PorterStemmer()
stemmed_words=[]
for w in filtered_words:
    stemmed_words.append(stem.stem(w))
print("Filtered Words:",filtered_words)
print("\n")
print("Stemmed Words:",stemmed_words)
# Out:
# Filtered Words: ['Dogs', ',', 'Canis', 'lupus', 'familiaris', ',', 'domesticated', 'mammals', ',', 'natural', 'wild', 'animals', '.', 'They', 'originally', 'bred', 'wolves', '.', 'They', 'bred', 'humans', 'long', 'time', ',', 'first', 'animals', 'ever', 'domesticated', '.', 'Today', ',', 'dogs', 'used', 'pets', ',', 'others', 'used', 'help', 'humans', 'work', '.', 'They', 'popular', 'pet', 'usually', 'playful', ',', 'friendly', ',', 'loyal', 'listen', 'humans', '.', 'Thirty', 'million', 'dogs', 'United', 'States', 'registered', 'pets', '.', 'Dogs', 'eat', 'meat', 'vegetables', ',', 'often', 'mixed', 'together', 'sold', 'stores', 'dog', 'food', '.', 'Dogs', 'often', 'jobs', ',', 'including', 'police', 'dogs', ',', 'army', 'dogs', ',', 'assistance', 'dogs', ',', 'fire', 'dogs', ',', 'messenger', 'dogs', ',', 'hunting', 'dogs', ',', 'herding', 'dogs', ',', 'rescue', 'dogs', '.', 'They', 'sometimes', 'called', '``', 'canines', "''", 'Latin', 'word', 'dog', '-', 'canis', '.', 'Sometimes', 'people', 'also', 'use', '``', 'dog', "''", 'describe', 'canids', ',', 'wolves', '.', 'A', 'baby', 'dog', 'called', 'pup', 'puppy', '.', 'A', 'dog', 'called', 'puppy', 'one', 'year', 'old', '.', 'Dogs', 'sometimes', 'referred', '``', 'man', '’', 'best', 'friend', "''", 'kept', 'domestic', 'pets', 'usually', 'loyal', 'like', 'around', 'humans', '.']
#
#
# Stemmed Words: ['dog', ',', 'cani', 'lupu', 'familiari', ',', 'domest', 'mammal', ',', 'natur', 'wild', 'anim', '.', 'they', 'origin', 'bred', 'wolv', '.', 'they', 'bred', 'human', 'long', 'time', ',', 'first', 'anim', 'ever', 'domest', '.', 'today', ',', 'dog', 'use', 'pet', ',', 'other', 'use', 'help', 'human', 'work', '.', 'they', 'popular', 'pet', 'usual', 'play', ',', 'friendli', ',', 'loyal', 'listen', 'human', '.', 'thirti', 'million', 'dog', 'unit', 'state', 'regist', 'pet', '.', 'dog', 'eat', 'meat', 'veget', ',', 'often', 'mix', 'togeth', 'sold', 'store', 'dog', 'food', '.', 'dog', 'often', 'job', ',', 'includ', 'polic', 'dog', ',', 'armi', 'dog', ',', 'assist', 'dog', ',', 'fire', 'dog', ',', 'messeng', 'dog', ',', 'hunt', 'dog', ',', 'herd', 'dog', ',', 'rescu', 'dog', '.', 'they', 'sometim', 'call', '``', 'canin', "''", 'latin', 'word', 'dog', '-', 'cani', '.', 'sometim', 'peopl', 'also', 'use', '``', 'dog', "''", 'describ', 'canid', ',', 'wolv', '.', 'a', 'babi', 'dog', 'call', 'pup', 'puppi', '.', 'a', 'dog', 'call', 'puppi', 'one', 'year', 'old', '.', 'dog', 'sometim', 'refer', '``', 'man', '’', 'best', 'friend', "''", 'kept', 'domest', 'pet', 'usual', 'loyal', 'like', 'around', 'human', '.']

# %% [markdown]
# every words in the sentence reduced to the shortest form

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()
word = "connecting"
lem.lemmatize(word, pos="v")
# Out:
# 'connect'

# %%
lem = WordNetLemmatizer()
word = "flying"
print(lem.lemmatize(word, pos="v"))
print(lem.lemmatize(word, pos="n"))
# Out:
# fly
# flying

# %% [markdown]
# seem pos="v" change inputed word to verb form, and pos="n" change to noun form

# %% [markdown]
# ## POS Tagging

# %%
sent = "I am studying at ICT"
tokens=nltk.word_tokenize(sent)
print(tokens)
nltk.pos_tag(tokens)
# Out:
# ['I', 'am', 'studying', 'at', 'ICT']
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('studying', 'VBG'),
#  ('at', 'IN'),
#  ('ICT', 'NNP')]

# %% [markdown]
# The function assign part-of-speech type to each word

# %% [markdown]
# PRP -> personal pronoun
#
# VBP -> verb, singular present, non-3rd person
#
# IN -> preposition/subordinating conjunction
#
# NNP -> proper noun, singular
#
# etc.
