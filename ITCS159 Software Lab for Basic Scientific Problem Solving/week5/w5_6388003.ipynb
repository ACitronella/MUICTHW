# %%
from IPython.display import Image
Image(url='http://www.billconnelly.net/wp-content/uploads/2021/05/PCA1-smaller-smaller.gif')
# Out:
# <img src="http://www.billconnelly.net/wp-content/uploads/2021/05/PCA1-smaller-smaller.gif"/>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# Normal distributed x and y vector with mean 0 and standard deviation 1
x = np.random.normal(0, 1, 500)
y = np.random.normal(0, 1, 500)
X = np.vstack((x, y)).T

plt.scatter(X[:, 0], X[:, 1])
plt.title('Generated Data')
plt.axis('equal');

# %%
# Covariance
def cov(x, y):
    xbar, ybar = x.mean(), y.mean()
    return np.sum((x - xbar)*(y - ybar))/(len(x) - 1)

# Covariance matrix
def cov_mat(X):
    return np.array([[cov(X[0], X[0]), cov(X[0], X[1])], \
                     [cov(X[1], X[0]), cov(X[1], X[1])]])

# %%
# Calculate covariance matrix 
cov_mat(X.T) # (or with np.cov(X.T))
# Out:
# array([[ 0.9768833 , -0.03903657],
#        [-0.03903657,  0.90774503]])

# %% [markdown]
# # Step 1

# %%
x = np.array([
    (-2, 1),
    (-3, 5),
    (-4, 3),
    (-5, 6),
    (-6, 7),
    (-7, 8)
])

# %% [markdown]
# # Step 2

# %%
mean_vec = x.mean(axis=0)
mean_vec
# Out:
# array([-4.5,  5. ])

# %% [markdown]
# # Step 3

# %%
dx = x - mean_vec
dx
# Out:
# array([[ 2.5, -4. ],
#        [ 1.5,  0. ],
#        [ 0.5, -2. ],
#        [-0.5,  1. ],
#        [-1.5,  2. ],
#        [-2.5,  3. ]])

# %% [markdown]
# # Step 4

# %%
cov_matrix = (dx.T @ dx)/dx.shape[0]
print(len(dx), dx.shape)
cov_matrix
# Out:
# 6 (6, 2)
# array([[ 2.91666667, -3.66666667],
#        [-3.66666667,  5.66666667]])

# %% [markdown]
# # Step 5

# %%
eigvals, eigvecs = np.linalg.eig(cov_matrix)
eigvals, eigvecs
# Out:
# (array([0.37566495, 8.20766838]),
#  array([[-0.82192562,  0.56959484],
#         [-0.56959484, -0.82192562]]))

# %% [markdown]
# # Step 6

# %%
# print(cov_matrix)
# v1 = eigvecs[:, 0]
# v2 = eigvecs[:, 1]
t1 = eigvals[0] * mean_vec
t2 = eigvals[1] * mean_vec

# z = cov_matrix @ mean_vec

plt.quiver(0, 0, mean_vec[0], mean_vec[1], angles='xy',scale_units='xy', scale=1, color="b")
plt.quiver(0, 0, t1[0], t1[1], angles='xy',scale_units='xy', scale=1, color="r")
plt.quiver(0, 0, t2[0], t2[1], angles='xy',scale_units='xy', scale=1, color="r")

# plt.quiver(0, 0, eigvals[1] * mean_vec[0], eigvals[1] * mean_vec[1], angles='xy',scale_units='xy', scale=1, color="r")
plt.quiver(0, 0, z[0], z[1], angles='xy',scale_units='xy', scale=1, color="g")
plt.xlim(-10, 2)
plt.ylim(-2, 10)
plt.scatter(x[:, 0], x[:, 1], color="b")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6968/605070231.py in <module>
#      12
#      13 # plt.quiver(0, 0, eigvals[1] * mean_vec[0], eigvals[1] * mean_vec[1], angles='xy',scale_units='xy', scale=1, color="r")
# ---> 14 plt.quiver(0, 0, z[0], z[1], angles='xy',scale_units='xy', scale=1, color="g")
#      15 plt.xlim(-10, 2)
#      16 plt.ylim(-2, 10)
#
# NameError: name 'z' is not defined

# %%
eigvals[1] * mean_vec[0], eigvals[1] * mean_vec[1]
# Out:
# (-36.934507724717406, 41.03834191635268)

# %%
z
# Out:
# array([-31.45833333,  44.83333333])
