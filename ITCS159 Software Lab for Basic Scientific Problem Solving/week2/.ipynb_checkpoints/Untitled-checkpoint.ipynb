# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(999)
N = 200
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-275b2be71999> in <module>
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 np.random.seed(999)
#       4 N = 200
#       5 x = np.random.rand(N)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-aa073c29deb1> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
#       3 df
#
# AttributeError: module 'pandas' has no attribute 'read_csv'

# %%
print(df)
# Out:
#         School  Women  Men  Gap
# 0          MIT     94  152   58
# 1     Stanford     96  151   55
# 2      Harvard    112  165   53
# 3       U.Penn     92  141   49
# 4    Princeton     90  137   47
# 5      Chicago     78  118   40
# 6   Georgetown     94  131   37
# 7        Tufts     76  112   36
# 8         Yale     79  114   35
# 9     Columbia     86  119   33
# 10        Duke     93  124   31
# 11   Dartmouth     84  114   30
# 12         NYU     67   94   27
# 13  Notre Dame     73  100   27
# 14     Cornell     80  107   27
# 15    Michigan     62   84   22
# 16       Brown     72   92   20
# 17    Berkeley     71   88   17
# 18       Emory     68   82   14
# 19        UCLA     64   78   14
# 20       SoCal     72   81    9

# %% [markdown]
# %%latex
# \begin{align}
# B'&=-\nabla \times E,\\
# E'&=\nabla \times B - 4\pi j, \\
# x &= \frac{-b\pm\sqrt{b^2-4ac}}{2a}
# \end{align}

# %% [markdown]
# \begin{align}
# \lim_{y \to \infty} \frac{\sin{((y))}}{y} = 0
# \end{align}

# %% [markdown]
# \begin{align}
# \frac{df}{dx}\Bigr|_{\substack{x=a}} = \lim_{h \to 0} \frac{f(a+h) - f(a)}{h}
# \end{align}
